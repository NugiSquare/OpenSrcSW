# %%
print("Type number X")

x = int(input())
y = 3*x^2 + 5*x + 3

print("The result is " + str(y))
# Out:
# Type number X
# 2
# The result is 9

# %%
print("Type half diameter r")

r = float(input())
s = r * r * 3.14

print("The result is " + str(s))
# Out:
# Type half diameter r
# 3
# The result is 28.26
